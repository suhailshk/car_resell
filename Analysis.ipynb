# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_csv('Dataset/cause_of_deaths.csv')

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %%
raw_data.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# ...

# %%
data1 = raw_data.groupby(['Country/Territory']).sum()
# Out:
# /tmp/ipykernel_44786/3730879266.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data1 = raw_data.groupby(['Country/Territory']).sum()

# %%
data1.drop(['Year'], axis=1)
# Out:
#                    Meningitis  Alzheimer's Disease and Other Dementias  \
# Country/Territory
# Afghanistan             78666                                    41998
# Albania                  1323                                    16549
# Algeria                 15685                                    86914
# American Samoa             30                                      143
# Andorra                     0                                      614
# ...                       ...                                      ...
# Venezuela               11615                                   108735
# Vietnam                 38559                                   369363
# Yemen                   21095                                    31045
# Zambia                  98886                                    13473
# Zimbabwe                41238                                    20017
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data1.iloc[0].plot(kind='pie', autopct = '%1.1f%%')
plt.show()

# %%
data1.iloc[0]
# Out:
# Year                                            60135
# Meningitis                                      78666
# Alzheimer's Disease and Other Dementias         41998
# Parkinson's Disease                             13397
# Nutritional Deficiencies                        71453
# Malaria                                         13924
# Drowning                                        56536
# Interpersonal Violence                         108228
# Maternal Disorders                             129621
# HIV/AIDS                                         4282
# Drug Use Disorders                               7094
# Tuberculosis                                   147637
# Cardiovascular Diseases                       1607042
# Lower Respiratory Infections                   822179
# Neonatal Disorders                             697534
# Alcohol Use Disorders                            3257
# Self-harm                                       37054
# ...

# %%
data1.drop(['Year'], axis=1, inplace=True)

# %%
data1.iloc[0]
# Out:
# Meningitis                                      78666
# Alzheimer's Disease and Other Dementias         41998
# Parkinson's Disease                             13397
# Nutritional Deficiencies                        71453
# Malaria                                         13924
# Drowning                                        56536
# Interpersonal Violence                         108228
# Maternal Disorders                             129621
# HIV/AIDS                                         4282
# Drug Use Disorders                               7094
# Tuberculosis                                   147637
# Cardiovascular Diseases                       1607042
# Lower Respiratory Infections                   822179
# Neonatal Disorders                             697534
# Alcohol Use Disorders                            3257
# Self-harm                                       37054
# Exposure to Forces of Nature                    16770
# ...

# %%
fatal = data1.iloc[0].sort_values(ascending=False).head(5)

# %%
explode = (0.1, 0.0, 0.2, 0.3, 0.1)
colors = ( "orange", "cyan", "brown",
          "grey", "indigo")

wp = { 'linewidth' : 1, 'edgecolor' : "black" }


fatal.plot(kind='pie', autopct = '%1.1f%%',explode = explode,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
# Out:
# <AxesSubplot: ylabel='Afghanistan'>
