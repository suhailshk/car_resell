# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
raw_data = pd.read_csv('Dataset/data_TV.csv')

# %%
raw_data.head()
# Out:
#   first_air_date origin_country original_language               name  \
# 0     2021-09-03             US                en  The D'Amelio Show
# 1     2008-01-20             US                en       Breaking Bad
# 2     2021-11-06             US                en             Arcane
# 3     2013-12-02             US                en     Rick and Morty
# 4     2022-04-14             US                en    The Kardashians
#
#    popularity  vote_average  vote_count  \
# 0      30.104           9.0        3071
# 1     468.253           8.8       10131
# 2      95.667           8.7        2615
# 3    1511.996           8.7        7220
# 4     195.038           8.7        1627
#
#                                             overview
# 0  From relative obscurity and a seemingly normal...
# 1  When Walter White, a New Mexico chemistry teac...
# 2  Amid the stark discord of twin cities Piltover...
# 3  Rick is a mentally-unbalanced but scientifical...
# ...

# %%
data1 = raw_data.groupby(['original_language']).count()
data1.head()
# Out:
#                    first_air_date  origin_country  name  popularity  \
# original_language
# ar                              2               2     2           2
# ca                              2               2     2           2
# da                              6               6     6           6
# de                             13              13    13          13
# en                           1682            1685  1685        1685
#
#                    vote_average  vote_count  overview
# original_language
# ar                            2           2         2
# ca                            2           2         2
# da                            6           6         6
# de                           13          13        13
# en                         1685        1685      1684

# %%
raw_data.groupby(['origin_country']).count().sort_values(['name'],ascending=False)
# Out:
#                                        first_air_date  original_language  \
# origin_country
# US                                               1376               1377
# JP                                                393                393
# GB                                                169                169
# MX                                                147                148
# KR                                                 98                 98
# ...                                               ...                ...
# c("DE", "US", "GB", "IT", "ZA", "TR")               1                  1
# c("DK", "US")                                       1                  1
# c("ES", "GB")                                       1                  1
# c("ES", "KN")                                       1                  1
# c("AT", "DE")                                       1                  1
#
#                                        name  popularity  vote_average  \
# ...

# %%
raw_data.sort_values(['popularity'], ascending=False)
# Out:
#      first_air_date origin_country original_language  \
# 179      2022-08-21             US                en
# 421      2022-09-21             US                en
# 1381     2022-09-01             US                en
# 2416     2022-08-18             US                en
# 3        2013-12-02             US                en
# ...             ...            ...               ...
# 2313     1988-10-18             US                en
# 542      2002-12-06             US                en
# 2211     1978-11-03             US                en
# 1630     1987-09-25             US                en
# 1334     1972-10-14             US                en
#
#                                             name  popularity  vote_average  \
# 179                          House of the Dragon    6684.611           8.5
# 421   Dahmer – Monster: The Jeffrey Dahmer Story    5865.900           8.3
# 1381   The Lord of the Rings: The Rings of Power    4787.462           7.7
# ...

# %%
pop_data = raw_data[['popularity', 'vote_average']]

# %%
pop_data.head()
# Out:
#    popularity  vote_average
# 0      30.104           9.0
# 1     468.253           8.8
# 2      95.667           8.7
# 3    1511.996           8.7
# 4     195.038           8.7

# %%
pop_data['vote'] = raw_data['vote_average']*raw_data['vote_count']
# Out:
# /tmp/ipykernel_51987/2494909941.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pop_data['vote'] = raw_data['vote_average']*raw_data['vote_count']

# %%
pop_data.head()
# Out:
#    popularity  vote_average     vote
# 0      30.104           9.0  27639.0
# 1     468.253           8.8  89152.8
# 2      95.667           8.7  22750.5
# 3    1511.996           8.7  62814.0
# 4     195.038           8.7  14154.9

# %%
plt.scatter(pop_data['popularity'], pop_data['vote'])

# %%
pop.data
